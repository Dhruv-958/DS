# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse

# %%
df = pd.read_csv("D:\Machine learning\datasets\BostonHousing.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\gurur\AppData\Local\Temp\ipykernel_12088\1318232821.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("D:\Machine learning\datasets\BostonHousing.csv")
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isna().sum()
df = df.dropna()

# %%
x = df.drop(columns=["medv"])
y = df["medv"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=32)
y_test.isna().sum()
# Out:
# 0

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([19.42104911, 29.69116429, 30.76740621, 24.2026522 , 17.69322855,
#        26.8859938 , 30.35773569, 28.99331212, 18.06445209, 27.61154349,
#        30.66714934, 15.4638394 , 12.62714422, 18.16316694, 22.14522075,
#        24.78677882,  9.17856102, 25.53325666, 22.51061327, 23.68793733,
#        19.44329183, 19.57579711, 32.88480749, 20.03698769, 12.86657602,
#        14.91971835, 25.21198995, 43.98349366, 18.21858678, 21.50551557,
#        20.83901051, 28.92876143, 17.38164573, 14.31252569, 26.1961561 ,
#        13.18836846, 35.16426475, 24.10118407, 33.62469983, 22.30257481,
#        33.61724738, 20.74414502, 31.92786477, 20.44222276, 19.40950587,
#        25.96014517, 16.89933836,  6.08086681, 27.83398983, 33.88724173,
#        36.53829112, 28.25317758, 36.099062  , 12.29275777, 29.55804179,
#        34.79754397, 17.91594474, 13.88087018, 13.65496508, 32.69523909,
#        23.31290711, 25.28023981, 18.46177713,  8.22425129, 19.45469215,
#        21.74203177, 25.32573787, 19.42801459, 21.5120838 , 35.40230723,
#        38.19388031, 25.39274539, 22.73504929, 22.37109609, 19.06843086,
#        13.84343447, 20.58128804, 18.80380072,  1.3068491 , 26.21091786,
#        19.39852172, 35.07746642, 20.076931  , 15.51776826, 14.96375029,
#        33.45388717, 13.51280017, 16.11091084, 13.26145007, 24.24606139,
#        17.36409665, 36.7249541 , 34.61338625, 20.35540271, 16.2326305 ,
#        24.08391322, 28.81309755, 22.78230721, 20.22854589, 36.31481708,
#        33.9156518 ])

# %%
err = mse(y_test,y_predict)

# %%
err
# Out:
# 20.582772285448716

# %%
root_err = np.sqrt(err)
root_err
# Out:
# 4.536824030690271

# %%
sns.scatterplot(x=y_test,y=y_predict, color='red')
# Out:
# <Axes: xlabel='medv'>
