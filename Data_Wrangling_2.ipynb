# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv-958/DS/blob/main/Data_Wrangling_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
stud_name = ["Student" + str(i) for i in range(30)]
math_scores = random.randint(60,80,30)
reading_scores = random.randint(75,95,30)
writing_scores = random.randint(60,80,30)
placement_scores = random.randint(75,100,30)
club_join_date = random.randint(2018,2021,30)

print(stud_name)
print(math_scores)
print(reading_scores)
print(writing_scores)
print(placement_scores)
print(club_join_date)
# Out:
# ['Student0', 'Student1', 'Student2', 'Student3', 'Student4', 'Student5', 'Student6', 'Student7', 'Student8', 'Student9', 'Student10', 'Student11', 'Student12', 'Student13', 'Student14', 'Student15', 'Student16', 'Student17', 'Student18', 'Student19', 'Student20', 'Student21', 'Student22', 'Student23', 'Student24', 'Student25', 'Student26', 'Student27', 'Student28', 'Student29']
# [65 65 61 73 79 72 77 70 76 71 74 73 77 78 72 71 65 78 69 76 78 78 68 75
#  66 60 68 68 79 61]
# [92 86 84 85 91 88 85 84 87 77 94 75 80 76 90 93 94 90 78 92 81 92 90 86
#  88 92 83 89 84 86]
# [66 69 62 60 63 70 78 61 77 61 76 64 65 70 64 66 75 69 71 61 62 71 79 75
#  71 75 60 70 78 70]
# [95 99 89 82 76 99 84 78 93 84 88 86 90 75 78 76 75 94 82 75 86 92 92 86
#  86 83 96 96 86 94]
# [2020 2020 2019 2019 2018 2018 2020 2020 2020 2020 2019 2018 2019 2020
#  2018 2020 2020 2019 2020 2020 2018 2019 2020 2018 2020 2019 2018 2020
#  2019 2019]

# %%
df = pd.DataFrame({
    "Student_Name" : stud_name,
    "Math_Score" : math_scores,
    "Reading_Score" : reading_scores,
    "Writing_Score" : writing_scores,
    "Placement_Score" : placement_scores,
    "Club_Join_Date" : club_join_date
})
df
# Out:
#    Student_Name  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0      Student0          65             92             66               95
# 1      Student1          65             86             69               99
# 2      Student2          61             84             62               89
# 3      Student3          73             85             60               82
# 4      Student4          79             91             63               76
# 5      Student5          72             88             70               99
# 6      Student6          77             85             78               84
# 7      Student7          70             84             61               78
# 8      Student8          76             87             77               93
# 9      Student9          71             77             61               84
# 10    Student10          74             94             76               88
# 11    Student11          73             75             64               86
# 12    Student12          77             80             65               90
# 13    Student13          78             76             70               75
# 14    Student14          72             90             64               78
# 15    Student15          71             93             66               76
# 16    Student16          65             94             75               75
# 17    Student17          78             90             69               94
# 18    Student18          69             78             71               82
# 19    Student19          76             92             61               75
# 20    Student20          78             81             62               86
# 21    Student21          78             92             71               92
# 22    Student22          68             90             79               92
# 23    Student23          75             86             75               86
# 24    Student24          66             88             71               86
# 25    Student25          60             92             75               83
# 26    Student26          68             83             60               96
# 27    Student27          68             89             70               96
# 28    Student28          79             84             78               86
# 29    Student29          61             86             70               94
#
#     Club_Join_Date
# 0             2020
# 1             2020
# 2             2019
# 3             2019
# 4             2018
# 5             2018
# 6             2020
# 7             2020
# 8             2020
# 9             2020
# 10            2019
# 11            2018
# 12            2019
# 13            2020
# 14            2018
# 15            2020
# 16            2020
# 17            2019
# 18            2020
# 19            2020
# 20            2018
# 21            2019
# 22            2020
# 23            2018
# 24            2020
# 25            2019
# 26            2018
# 27            2020
# 28            2019
# 29            2019

# %%
df.shape
# Out:
# (30, 6)

# %%
df.isnull().sum()
# Out:
# Student_Name       0
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join_Date     0
# dtype: int64

# %% [markdown]
# # **Z_SCORES**

# %%
data1 = np.array([2,4,5,6,3,5,67,3,65,78])
z_scores = stats.zscore(data1)
t = 2.5
outliers = np.where(np.abs(z_scores) > t)[0]
z_scores
# Out:
# array([-0.71648531, -0.65075271, -0.61788641, -0.58502011, -0.68361901,
#        -0.61788641,  1.41982409, -0.68361901,  1.35409149,  1.78135337])

# %%
print("Outliers: ", data1[outliers])
# Out:
# Outliers:  []

# %% [markdown]
# # **IQR**

# %%
data2 = np.array([2,4,5,6,3,5,14,3,17,20,100])
data2
# Out:
# array([  2,   4,   5,   6,   3,   5,  14,   3,  17,  20, 100])

# %%
plt.boxplot(data2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80cf11afb0>,
#   <matplotlib.lines.Line2D at 0x7f80cf11ba90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80cf1197e0>,
#   <matplotlib.lines.Line2D at 0x7f80cf11bbe0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80cf11a5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80cf119db0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80cf566dd0>],
#  'means': []}

# %%
median = np.median(data2)
median
# Out:
# 5.0

# %%
Q1 = [i for i in data2 if i<median]
Q3 = [i for i in data2 if i>median]
print("Q1: ", Q1, "\nQ3: ", Q3)
# Out:
# Q1:  [2, 4, 3, 3]
# Q3:  [6, 14, 17, 20, 100]

# %%
Q1_med = np.median(Q1)
Q3_med = np.median(Q3)
print("Q1: ", Q1_med, "\nQ3: ", Q3_med)
IQR = Q3_med - Q1_med
print("IQR: ", IQR)
# Out:
# Q1:  3.0
# Q3:  17.0
# IQR:  14.0

# %%
new_data2 = data2[data2!=100]
print(new_data2)
plt.boxplot(new_data2)
# Out:
# [ 2  4  5  6  3  5 14  3 17 20]
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80cceffb80>,
#   <matplotlib.lines.Line2D at 0x7f80cceffe20>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80cce50100>,
#   <matplotlib.lines.Line2D at 0x7f80cce503a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80cceff8e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80cce50640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80cce508e0>],
#  'means': []}

# %% [markdown]
# # **Normalizing Values**

# %%
data3 = data2
print(data3)
min = np.min(data3)
max = np.max(data3)
print("Min: ", min, "\nMax: ", max)
# Out:
# [  2   4   5   6   3   5  14   3  17  20 100]
# Min:  2
# Max:  100

# %%
normalized_values = [(i-min)/(max-min) for i in data3]
print(normalized_values)
# Out:
# [0.0, 0.02040816326530612, 0.030612244897959183, 0.04081632653061224, 0.01020408163265306, 0.030612244897959183, 0.12244897959183673, 0.01020408163265306, 0.15306122448979592, 0.1836734693877551, 1.0]

# %%
d3_dtype= data3.dtype

# %%
data3.astype(str)
# Out:
# array(['2', '4', '5', '6', '3', '5', '14', '3', '17', '20', '100'],
#       dtype='<U21')

# %%
dataset['Club_Join_Date'] = df['Club_Join_Date'].replace({2018 : 1, 2019 : 2, 2020 : 3})
print(dataset)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0           60             86             67               77               3
# 1           78             82             61               76               3
# 2           67             76             67               96               2
# 3           63             86             79               89               2
# 4           70             85             73               79               1
# 5           78             79             78               88               1
# 6           73             91             70               80               3
# 7           61             89             60               82               3
# 8           79             83             74               77               3
# 9           63             89             67               81               3
# 10          70             89             75               84               2
# 11          72             88             65               87               1
# 12          67             90             74               84               2
# 13          65             84             78               98               3
# 14          66             79             74               87               1
# 15          61             79             60               85               3
# 16          77             77             75               82               3
# 17          67             79             68               82               2
# 18          69             85             76               88               3
# 19          65             76             72               93               3
# 20          76             80             76               98               1
# 21          73             81             62               91               2
# 22          61             83             65               85               3
# 23          60             92             63               88               1
# 24          75             92             77               84               3
# 25          79             77             78               95               2
# 26          66             94             68               89               1
# 27          76             79             62               91               3
# 28          71             83             71               84               2
# 29          61             85             77               96               2

# %%
def insertNulls(df) :
  nulls = 5;
  for i in range (nulls) :
    randIndex = random.randint(0,30)
    df.at[randIndex, "Placement_Score"] = np.nan

insertNulls(df)
df
# Out:
#    Student_Name  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0      Student0          65             92             66             95.0
# 1      Student1          65             86             69             99.0
# 2      Student2          61             84             62             89.0
# 3      Student3          73             85             60             82.0
# 4      Student4          79             91             63              NaN
# 5      Student5          72             88             70             99.0
# 6      Student6          77             85             78             84.0
# 7      Student7          70             84             61              NaN
# 8      Student8          76             87             77             93.0
# 9      Student9          71             77             61              NaN
# 10    Student10          74             94             76              NaN
# 11    Student11          73             75             64             86.0
# 12    Student12          77             80             65              NaN
# 13    Student13          78             76             70             75.0
# 14    Student14          72             90             64             78.0
# 15    Student15          71             93             66              NaN
# 16    Student16          65             94             75              NaN
# 17    Student17          78             90             69             94.0
# 18    Student18          69             78             71             82.0
# 19    Student19          76             92             61             75.0
# 20    Student20          78             81             62             86.0
# 21    Student21          78             92             71              NaN
# 22    Student22          68             90             79             92.0
# 23    Student23          75             86             75             86.0
# 24    Student24          66             88             71              NaN
# 25    Student25          60             92             75              NaN
# 26    Student26          68             83             60             96.0
# 27    Student27          68             89             70             96.0
# 28    Student28          79             84             78             86.0
# 29    Student29          61             86             70             94.0
#
#     Club_Join_Date
# 0             2020
# 1             2020
# 2             2019
# 3             2019
# 4             2018
# 5             2018
# 6             2020
# 7             2020
# 8             2020
# 9             2020
# 10            2019
# 11            2018
# 12            2019
# 13            2020
# 14            2018
# 15            2020
# 16            2020
# 17            2019
# 18            2020
# 19            2020
# 20            2018
# 21            2019
# 22            2020
# 23            2018
# 24            2020
# 25            2019
# 26            2018
# 27            2020
# 28            2019
# 29            2019

# %%
df1 = df.dropna()

# %%
df1
# Out:
#    Student_Name  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0      Student0          65             92             66             95.0
# 1      Student1          65             86             69             99.0
# 2      Student2          61             84             62             89.0
# 3      Student3          73             85             60             82.0
# 5      Student5          72             88             70             99.0
# 6      Student6          77             85             78             84.0
# 8      Student8          76             87             77             93.0
# 11    Student11          73             75             64             86.0
# 13    Student13          78             76             70             75.0
# 14    Student14          72             90             64             78.0
# 17    Student17          78             90             69             94.0
# 18    Student18          69             78             71             82.0
# 19    Student19          76             92             61             75.0
# 20    Student20          78             81             62             86.0
# 22    Student22          68             90             79             92.0
# 23    Student23          75             86             75             86.0
# 26    Student26          68             83             60             96.0
# 27    Student27          68             89             70             96.0
# 28    Student28          79             84             78             86.0
# 29    Student29          61             86             70             94.0
#
#     Club_Join_Date
# 0             2020
# 1             2020
# 2             2019
# 3             2019
# 5             2018
# 6             2020
# 8             2020
# 11            2018
# 13            2020
# 14            2018
# 17            2019
# 18            2020
# 19            2020
# 20            2018
# 22            2020
# 23            2018
# 26            2018
# 27            2020
# 28            2019
# 29            2019
